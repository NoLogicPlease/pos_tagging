# %% [markdown]
# # ASSIGNMENT 1 - POS Tagging
#
# Cristian Sherban Tudosie, Francesco Vannoni, Mirko del Moro

# %% [markdown]
# #IMPORTS

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.regularizers import l2

import copy
import os
import re
import math
import tarfile
import zipfile
import random
import numpy as np
import pandas as pd
from tqdm import tqdm
from urllib import request
import collections
import sklearn.metrics as sk_metrics
import pickle

# %%
#installing correct version packages
! pip install keras_tuner
import keras_tuner as kt # hyperparameter tuner
# In order to use key_to_index attribute from the embedding model
! pip install gensim==4.1.2
import gensim
import gensim.downloader as gloader
! pip install matplotlib==3.5.0
import matplotlib.pyplot as plt
# Out:
# Collecting keras_tuner
#   Downloading keras_tuner-1.1.0-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 5.0 MB/s
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (2.23.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (2.7.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (1.4.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (5.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras_tuner) (1.19.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (5.1.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (1.0.18)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (0.8.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->keras_tuner) (4.4.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->keras_tuner) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->keras_tuner) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->keras_tuner) (3.0.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->keras_tuner) (0.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->keras_tuner) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->keras_tuner) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->keras_tuner) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->keras_tuner) (1.24.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (0.37.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (1.42.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (1.35.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (0.12.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (3.3.6)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras_tuner) (3.17.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard->keras_tuner) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras_tuner) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras_tuner) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras_tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner) (3.1.1)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.1.0 kt-legacy-1.0.4
# Requirement already satisfied: gensim==4.1.2 in /usr/local/lib/python3.7/dist-packages (4.1.2)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from gensim==4.1.2) (1.19.5)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim==4.1.2) (5.2.1)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim==4.1.2) (1.4.1)
# Requirement already satisfied: matplotlib==3.5.0 in /usr/local/lib/python3.7/dist-packages (3.5.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.0) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.0) (7.1.2)
# Requirement already satisfied: setuptools-scm>=4 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.0) (6.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.0) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.0) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.0) (3.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.0) (4.28.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.0) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib==3.5.0) (1.15.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from setuptools-scm>=4->matplotlib==3.5.0) (1.2.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from setuptools-scm>=4->matplotlib==3.5.0) (57.4.0)

# %%
EMBEDDING_SIZE = 100
BATCH_SIZE = 64
TRAINING = True
TRAINING_BEST = True

# %%
def fix_random(seed: int) -> None:
    """Fix all the possible sources of randomness.

    Args:
        seed: the seed to use. 
    """
    np.random.seed(seed)
    random.seed(seed)    
    
fix_random(42)

# %% [markdown]
# #PRE-PROCESSING

# %%
def download_dataset(download_path: str, url: str):  
    # download dataset
    if not os.path.exists(download_path):
        print("Downloading dataset...")
        request.urlretrieve(url, download_path)
        print("Download complete!")


def extract_dataset(download_path: str, extract_path: str):  
    # extract dataset
    print("Extracting dataset... (it may take a while...)")
    with zipfile.ZipFile(download_path, 'r') as loaded_zip:
        loaded_zip.extractall(extract_path)
    print("Extraction completed!")


def encode_dataset(dataset_path: str, dataset_folder: str, debug: bool = True):
    # dataset to dataframe
    dataframe_rows = []
    s_lengths_orig = []
    s_lengths_clean = []
    deleted = 0
    for index, file in tqdm(enumerate(sorted(os.listdir(dataset_path)))):
        file_name = os.path.join(dataset_path, file)
        with open(file_name) as f:
            lines = f.readlines()
        # since lines is a list we use a single string called full_file
        full_file = ''.join(lines)  
        # remove numbers from each lines of dataset
        full_file = re.sub(r'(\t\d+)', '', full_file)  
        # replace \t with a space
        full_file = re.sub(r'(\t)', ' ', full_file)  
        sentences = full_file.split('\n\n')
        # separate all words from their tags
        for s in sentences:  
            # find all text
            text = ''.join(re.findall(r'.+ ', s)) 
            # find labels
            labels = ''.join(re.findall(r' .+', s)) 
            # substitute blank space-word with word
            labels = re.sub(r' (.+)', r'\1 ', labels)
            # remove new line
            labels = re.sub('\n', ' ', labels) 
            s_lengths_orig.append(len(labels.split(' ')))
            # split into train, val and test
            if index <= 100:
                split = 'train'
            elif 100 < index <= 150:
                split = 'val'
            else:
                split = 'test'

            if len(labels.split(' ')) <= 80 and (split == "train" or split =="val"):
                # create a single row of dataframe
                s_lengths_clean.append(len(labels.split(' ')))
                dataframe_row = {
                    "text": text,
                    "POStagging": labels,
                    "split": split,
                }
                dataframe_rows.append(dataframe_row)
            # delete train and val sentences longer than 80
            elif len(labels.split(' ')) > 80 and (split == "train" or split == "val"): 
                deleted += 1
            # if test append sentence of any length and don't remove
            if split == "test":
                dataframe_row = {
                    "text": text,
                    "POStagging": labels,
                    "split": split,
                }
                dataframe_rows.append(dataframe_row)

    print(f"We deleted {deleted} sentences from train!")
    print(f"The dataset has on average {np.mean(s_lengths_orig)} words per sentence")
    plt.title("Boxplot of word counts per sentence")
    plt.boxplot(s_lengths_orig)
    plt.show()
    # transform the list of rows in a proper dataframe
    df = pd.DataFrame(dataframe_rows)
    df = df[["text",
             "POStagging",
             "split"]]
    print("Max length of a sentence in validation and test")
    print(max(df[df["split"] == "val"]["POStagging"].str.split().str.len()))
    print(max(df[df["split"] == "test"]["POStagging"].str.split().str.len()))
    print("Number of elements exceeding the length of the train")
    print(len(df[df["split"]=="val"][df[df["split"] == "val"]["POStagging"].str.split().str.len() > 80]))
    print(len(df[df["split"]=="test"][df[df["split"] == "test"]["POStagging"].str.split().str.len() > 80]))
    dataframe_path = os.path.join(dataset_folder, "dependency_treebank_df.pkl")
    # save dataframe in a pickle file
    df.to_pickle(dataframe_path)
    return df, max(s_lengths_clean)


def create_dataset(): 
    # download, extract, encode and return dataset
    dataset_folder = os.path.join(os.getcwd(), "Datasets")
    if not os.path.exists(dataset_folder):
        os.makedirs(dataset_folder)

    url = "https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/packages/corpora/dependency_treebank.zip"

    dataset_path_zip = os.path.join(dataset_folder, "dependency_treebank.zip")
    download_dataset(dataset_path_zip, url)
    extract_dataset(dataset_path_zip, dataset_folder)
    dataset_path = os.path.join(dataset_folder, "dependency_treebank")
    df, max_seq_len = encode_dataset(dataset_path, dataset_folder)
    df['POStagging'] = df['POStagging'].str.lower()
    df['text'] = df['text'].str.lower()
    return df, max_seq_len


def create_trainable(dataset, value_to_key, max_seq_len, num_classes, label_tokenizer=None): 
    # create x_train and y_train
    text_ids = [[value_to_key[word] for word in sen.split()] for sen in dataset['text']]
    x_train = []
    y_train = []
    # dictionary as tokenizer for the labels
    label_tokenizer = {} if label_tokenizer == None else label_tokenizer 

    one_hot_idx = 1
    # add padding label as one hot encoding
    label_tokenizer["<PAD>"] = [1 if i == 0 else 0 for i in range(num_classes)]
    for sen, tagging in zip(text_ids, dataset["POStagging"]):
        # pad sentence
        tmp = [0] * (max_seq_len - len(sen)) + sen 
        x_train.append(tmp)

        for label in tagging.split():
            try:
                check_label = label_tokenizer[label]
            except KeyError:
                # add label as one hot encoding
                label_tokenizer[label] = [1 if i == one_hot_idx else 0 for i in range(num_classes)]
                one_hot_idx += 1

        # pad labels
        tmp = [[0] * num_classes] * (max_seq_len - len(sen)) + [label_tokenizer[e] for e in tagging.split()] 
        y_train.append(tmp)
    return np.array(x_train), np.array(y_train), label_tokenizer


def get_num_classes(dataset):
    return len(np.unique(''.join(dataset["POStagging"]).split())) + 1  # +1 for the padding

#########################################

'''
IF YOU WANT TO USE DRIVE UNCOMMENT

try:
    from google.colab import drive
    IN_COLAB=True
except:
    IN_COLAB=False

if IN_COLAB:
    print("We're running Colab")
    # Mount the Google Drive at mount
    mount='/content/gdrive'
    print("Colab: mounting Google drive on ", mount)
    drive.mount(mount)

    # Switch to the directory on the Google Drive that you want to use
    drive_root = mount + "/My Drive/NLP/Assignment1"
    
    # Create drive_root if it doesn't exist
    create_drive_root = True
    if create_drive_root:
        print("\nColab: making sure ", drive_root, " exists.")
        os.makedirs(drive_root, exist_ok=True)
    
    # Change to the directory
    print("\nColab: Changing directory to ", drive_root)
    # %cd $drive_root
    # %pwd'''

# To download uncomment the following: 
create_dataset()
# Out:
# Downloading dataset...
# Download complete!
# Extracting dataset... (it may take a while...)
# Extraction completed!
# 199it [00:00, 854.86it/s]
# We deleted 7 sentences from train!
# The dataset has on average 25.037812979049566 words per sentence
# Max length of a sentence in validation and test
# 75
# 58
# Number of elements exceeding the length of the train
# 0
# 0
# (                                                   text  ...  split
#  0     pierre vinken , 61 years old , will join the b...  ...  train
#  1     mr. vinken is chairman of elsevier n.v. , the ...  ...  train
#  2     rudolph agnew , 55 years old and former chairm...  ...  train
#  3     a form of asbestos once used to make kent ciga...  ...  train
#  4     the asbestos fiber , crocidolite , is unusuall...  ...  train
#  ...                                                 ...  ...    ...
#  3902  they also said that more than a dozen presiden...  ...   test
#  3903  sen. kennedy said in a separate statement that...  ...   test
#  3904  trinity industries inc. said it reached a prel...  ...   test
#  3905                        terms were n't disclosed .   ...   test
#  3906  trinity said it plans to begin delivery in the...  ...   test
#
#  [3907 rows x 3 columns], 79)

# %% [markdown]
# #CLASSES

# %% [markdown]
# ##Tokenizer

# %%
class Tokenizer(object):
    def __init__(self, dataset_sentences, embedding_dim, glove_dict, glove_matrix):
        """
            dataset_sentences : sentences to be tokenized in form of strings
            embedding_dim : size of the embeddings
            glove_dict : glove dictionary
            glove_matrix : glove matrix
        """
        self.embedding_matrix = None
        #word to token dictionary
        self.value_to_key = {}
        #useful for implementation, contains only new OOV terms
        self.value_to_key_new = {} 
        self.num_unique_words = 0
        #word to token
        self.key_to_value = {} 
        self.dataset_sentences = dataset_sentences 
        self.embedding_dim = embedding_dim
        self.glove_dict = glove_dict
        self.glove_matrix = glove_matrix 
        #set containing all the words of the vocabulary, update after the processing of each split
        self.unique_words = set()

    def get_val_to_key(self):
        return copy.deepcopy(self.value_to_key)

    def tokenize(self):
        """
            create and/or upload tokenizer. Each time that a new word is passed
            from a sentence, check if it has already been tokenized otherwise 
            tokenize it and add to the vocabulary. 
        """
        self.value_to_key_new = {}
        unique_words = set()
        for sen in self.dataset_sentences:
            for w in sen.split():
                # get set of unique words
                unique_words.add(w)  
        #new unique are the words not still processed
        new_unique = unique_words - self.unique_words 
        for i, word in enumerate(new_unique):
            #it means we are in the validation or test set, the embedding has already been created and updated by the train
            if self.embedding_matrix is not None: 
                #tokenization
                self.key_to_value[i + len(self.embedding_matrix)] = word  
                self.value_to_key[word] = i + len(self.embedding_matrix)
            else:
                #first time we are tokenizing (train), don't need to add len
                self.key_to_value[i] = word 
                self.value_to_key[word] = i
            self.value_to_key_new[word] = i

        self.num_unique_words = len(new_unique)
        #update unique words with new unique
        self.unique_words = self.unique_words | new_unique  

    def __build_embedding_matrix_glove(self):
        """
            create the embedding matrix. The rows corresponding to the words
            contained in glove will be filled. If a word is not in glove the
            word and its index are saved in order to be processed later.   
        """
        oov_words = []
        tmp_embedding_matrix = np.zeros((self.num_unique_words, self.embedding_dim)) #dtype=np.float32
        len_old_emb_matrix = len(self.embedding_matrix) if self.embedding_matrix is not None else 0
        for word, idx in tqdm(self.value_to_key_new.items()):
            try:
                embedding_vector = self.glove_matrix[self.glove_dict[word]]
                #create tmp embedding matrix to be concatenated to the original embedding matrix
                tmp_embedding_matrix[idx] = embedding_vector 
            except (KeyError, TypeError):
                oov_words.append((word, idx + len_old_emb_matrix))
        
        if self.embedding_matrix is not None:
            #concatenate old embedding matrix and new one (new OOVs)
            self.embedding_matrix = np.vstack((self.embedding_matrix, tmp_embedding_matrix)) 
        else:
            self.embedding_matrix = copy.deepcopy(tmp_embedding_matrix)
        return oov_words

    def build_embedding_matrix(self):
        """
            create embedding vector for OOV words. If a word has at least two
            neghbours (previous and next word) in glove, compute it as average 
            of their embeddings, otherwise values follow uniform distribution  
        """
        oov_words = self.__build_embedding_matrix_glove()
        for word, idx in oov_words:
            neighbour_words = []
            # look for word in sentence
            for sen in self.dataset_sentences: 
                for i, wanted_word in enumerate(sen):
                    if wanted_word == word:
                        # append previous word in list of neighbours
                        neighbour_words.append(sen[i - 1])  
                        # append next word in list of neighbours
                        neighbour_words.append(sen[i + 1]) 
            # initialize matrix of avgs
            avg_matrix = np.zeros((len(neighbour_words), self.embedding_dim)) 

            # to check if neighbours are OOV
            length_in_vocab = 0  
            for i, el in enumerate(neighbour_words):
                try:
                    # check not OOV
                    avg_matrix[i] = self.embedding_matrix[self.value_to_key[el]]  
                    length_in_vocab += 1 
                except (KeyError, TypeError):  
                    pass
            #if there is one or less random.uniform
            if length_in_vocab <= 1:
                embedding_vector = np.random.uniform(low=-0.05, high=0.05, size=self.embedding_dim)
            else:
                #compute avg
                embedding_vector = np.mean(avg_matrix[:length_in_vocab], axis=0)
            self.embedding_matrix[idx] = embedding_vector
        return copy.deepcopy(self.embedding_matrix)

# %% [markdown]
# ##Model

# %%
class Model(object):
    def __init__(self, model_type, compile_info, value_to_key, embedding_dim, max_seq_len, num_labels,
                 embedding_matrix, num_recurrent_units, l2_reg):
        
        """
            model_type : specify the type of model (baseline, gru, two lstm, two dense)
            compile_info : information to compile (optimizer, loss, metrics)
            value_to_key : value to token from tokenizer
            embedding_dim : dimension of the embeddings
            max_seq_len : maximum length of a sentence
            num_labels : number of different POS tags
            embedding_matrix : embedding matrix created in the tokenizer
            num_recurrent_units : number of units for the RNN
            l2_reg :L2 regularizer value
        """

        self.compile_info = compile_info
        self.value_to_key = value_to_key 
        self.embedding_dim = embedding_dim
        self.max_seq_len = max_seq_len
        self.num_labels = num_labels
        self.embedding_matrix = embedding_matrix
        self.num_recurrent_units = num_recurrent_units
        self.l2_reg = l2_reg
        self.name = model_type

        if 'baseline' == model_type:
            self.model = self.create_LSTM()
        elif 'gru' == model_type:
            self.model = self.create_GRU()
        elif 'two_lstm' == model_type:
            self.model = self.create_two_LSTM()
        else:
            self.model = self.create_two_Dense()


    def create_LSTM(self) -> keras.Model:
        inputs = keras.layers.Input(shape=(None,))
        x = layers.Embedding(input_dim=len(self.value_to_key.keys()) + 1,
                                            output_dim=self.embedding_dim,
                                            mask_zero = True,
                                            input_length=self.max_seq_len,
                                            weights=[self.embedding_matrix],
                                            trainable=False
                                            )(inputs)

        x = layers.Bidirectional(layers.LSTM(self.num_recurrent_units, return_sequences=True, kernel_regularizer=l2(self.l2_reg)))(x)
        print(x)
        outputs = layers.TimeDistributed(layers.Dense(self.num_labels, activation="softmax"))(x)
        bidirect_model = keras.Model(inputs=inputs, outputs=outputs)
        bidirect_model.compile(**self.compile_info)
        bidirect_model.summary()
        return bidirect_model

    def create_GRU(self) -> keras.Model:
        gru = keras.models.Sequential()
        gru.add(layers.Embedding(input_dim=len(self.value_to_key.keys()) + 1,
                                 output_dim=self.embedding_dim,
                                 input_length=self.max_seq_len,
                                 mask_zero=True,
                                 weights=[self.embedding_matrix],
                                 trainable=False
                                 ))

        gru.add(layers.GRU(self.num_recurrent_units, return_sequences=True, kernel_regularizer=l2(self.l2_reg)))
        gru.add(layers.TimeDistributed(layers.Dense(self.num_labels, activation="softmax")))
        gru.compile(**self.compile_info)
        gru.summary()
        return gru

    def create_two_LSTM(self) -> keras.Model:
        lstm = keras.models.Sequential()
        lstm.add(layers.Embedding(input_dim=len(self.value_to_key.keys()) + 1,
                                  output_dim=self.embedding_dim,
                                  input_length=self.max_seq_len,
                                  mask_zero=True,
                                  weights=[self.embedding_matrix],
                                  trainable=False
                                  ))

        lstm.add(layers.Bidirectional(layers.LSTM(self.num_recurrent_units, return_sequences=True, kernel_regularizer=l2(self.l2_reg))))
        lstm.add(layers.LSTM(self.num_recurrent_units//2, return_sequences=True))
        lstm.add(layers.TimeDistributed(layers.Dense(self.num_labels, activation="softmax")))
        lstm.compile(**self.compile_info)
        lstm.summary()
        return lstm

    def create_two_Dense(self) -> keras.Model:
        lstm = keras.models.Sequential()
        lstm.add(layers.Embedding(input_dim=len(self.value_to_key.keys()) + 1,
                                  output_dim=self.embedding_dim,
                                  input_length=self.max_seq_len,
                                  mask_zero=True,
                                  weights=[self.embedding_matrix],
                                  trainable=False
                                  ))
        lstm.add(layers.Bidirectional(layers.LSTM(self.num_recurrent_units, return_sequences=True, kernel_regularizer=l2(self.l2_reg))))
        lstm.add(layers.TimeDistributed(layers.Dense(self.num_recurrent_units*2, activation="relu")))
        lstm.add(layers.TimeDistributed(layers.Dense(self.num_labels, activation="softmax")))
        lstm.compile(**self.compile_info)
        lstm.summary()
        return lstm

    def show_history(self, history: keras.callbacks.History):

        history_data = history.history
        print("Displaying the following history keys: ", history_data.keys())

        for key, value in history_data.items():
            if not key.startswith('val'):
                fig, ax = plt.subplots(1, 1)
                ax.set_title(key)
                ax.plot(value)
                if 'val_{}'.format(key) in history_data:
                    ax.plot(history_data['val_{}'.format(key)])
                else:
                    print("Couldn't find validation values for metric: ", key)

                ax.set_ylabel(key)
                ax.set_xlabel('epoch')
                ax.legend(['train', 'val'], loc='best')

        plt.show()

    def train_model(self,
                    x_train: np.ndarray,
                    y_train: np.ndarray,
                    x_val: np.ndarray,
                    y_val: np.ndarray,
                    training_info: dict):
        print("Start training! \nParameters: {}".format(training_info))
        history = self.model.fit(x=x_train, y=y_train,
                                 validation_data=(x_val, y_val),
                                 shuffle=True,
                                 **training_info)
        print("Training completed! Showing history...")

        self.show_history(history)

# %% [markdown]
# #MAIN

# %%
#create dataset
df, max_seq_len = create_dataset()


try:
    with open(f"glove-{EMBEDDING_SIZE}.pkl", 'rb') as f:
        emb_model = pickle.load(f)
except Exception:
    emb_model = gloader.load(f"glove-wiki-gigaword-{EMBEDDING_SIZE}")
    with open(f"glove-{EMBEDDING_SIZE}.pkl", 'wb') as f:
        pickle.dump(emb_model, f)

#glove dictionary
glove_dict = emb_model.key_to_index
#glove matrix
glove_matrix = emb_model.vectors

'''
    if it exist, download embedding matrix and word to token dictionary
    otherwise create it
'''

try:
    with open("emb_mat.pkl", 'rb') as f:
        v4_matrix = pickle.load(f)
    with open("val_to_key.pkl", 'rb') as f:
        v4_val_to_key = pickle.load(f)
except Exception:
    #tokenize train
    tokenizer = Tokenizer(df[df['split'] == 'train']['text'], EMBEDDING_SIZE, glove_dict, glove_matrix)
    tokenizer.tokenize()
    v2_matrix = tokenizer.build_embedding_matrix()
    #tokenize val concatenating to train
    tokenizer.dataset_sentences = df[df['split'] == 'val']['text']
    tokenizer.tokenize()
    v3_matrix = tokenizer.build_embedding_matrix()
    #tokenize test concatenating to train and val
    tokenizer.dataset_sentences = df[df['split'] == 'test']['text']
    tokenizer.tokenize()
    v4_matrix = tokenizer.build_embedding_matrix()
    v4_val_to_key = tokenizer.get_val_to_key()
    with open(f"emb_mat.pkl", 'wb') as f:
        pickle.dump(v4_matrix, f)
    with open(f"val_to_key.pkl", 'wb') as f:
        pickle.dump(v4_val_to_key, f)

#add one to all the tokens id to reserve 0 for padding
v4_val_to_key.update((x, y+1) for x, y in v4_val_to_key.items())

num_classes = get_num_classes(df[df['split'] == 'train'])
#create x_train and y_train
x_train, y_train, tok = create_trainable(df[df['split'] == 'train'], 
                                         v4_val_to_key, 
                                         max_seq_len,
                                         num_classes=num_classes)
#create x_val and y_val
x_val, y_val, tok = create_trainable(df[df['split'] == 'val'], 
                                     v4_val_to_key, 
                                     max_seq_len, 
                                     num_classes=num_classes, 
                                     label_tokenizer=tok)
#create x_test and y_test
x_test, y_test, tok = create_trainable(df[df['split'] == 'test'], 
                                       v4_val_to_key,
                                       max_seq_len, 
                                       num_classes=num_classes, 
                                       label_tokenizer=tok)
# Out:
# Extracting dataset... (it may take a while...)
# Extraction completed!
# 199it [00:00, 1472.39it/s]
# We deleted 7 sentences from train!
# The dataset has on average 25.037812979049566 words per sentence
# Max length of a sentence in validation and test
# 75
# 58
# Number of elements exceeding the length of the train
# 0
# 0
# 100%|██████████| 7355/7355 [00:00<00:00, 426870.90it/s]
# 100%|██████████| 2438/2438 [00:00<00:00, 318379.51it/s]
# 100%|██████████| 1039/1039 [00:00<00:00, 264932.94it/s]

# %%
'''
    check how many elements there are for any tag. 
    Plot histogram showing it
'''

tmp_list = ' '.join(df[df["split"] == "train"]["POStagging"]).split()
import collections
counter = collections.Counter(tmp_list)
print(counter)
plt.rcParams['figure.figsize'] = [15, 8]
plt.bar(counter.keys(), counter.values())
plt.show()
# Out:
# Counter({'nn': 6344, 'nnp': 5067, 'in': 5036, 'dt': 4165, 'nns': 3034, 'jj': 3029, ',': 2483, '.': 1976, 'vbd': 1559, 'rb': 1511, 'cd': 1433, 'vb': 1207, 'vbz': 1150, 'cc': 1143, 'to': 1047, 'vbn': 1046, 'prp': 955, 'vbg': 778, 'vbp': 731, 'md': 417, 'prp$': 411, '``': 409, 'pos': 405, "''": 399, '$': 312, ':': 247, 'wdt': 207, 'jjr': 160, 'wp': 142, 'rp': 140, 'nnps': 98, 'jjs': 94, 'wrb': 90, 'rbr': 88, '-rrb-': 56, '-lrb-': 53, 'ex': 49, 'rbs': 20, 'ls': 10, 'pdt': 9, 'wp$': 6, 'fw': 1, 'uh': 1, 'sym': 1, '#': 1})

# %%
'''
    checking code for the dataset.
    Check the number and the name of the tags. 
    Check the number of unique words for the training, validation and test set.
'''
print(np.unique(''.join(df['POStagging']).split()))
print("Unique classes ",len(np.unique(''.join(df['POStagging']).split())))

vali = df[df['split']=='val']
traini = df[df['split']=='train']

uni_vali = set(''.join(vali['text']).split())
uni_traini = set(''.join(traini['text']).split())

diff = uni_vali - (uni_traini & uni_vali)


print()
print(f"[Training] unique words: \t{len(uni_traini)}")
print(f"[Training & Val] unique words: \t{len(uni_traini & uni_vali)}")
print(f"[Val] unique word: \t{len(uni_vali)}  (val tolale)") 
print(f"Difference [Val - (Training & Val)] unique words: \t{len(diff)}  (val che non sta in train)")

uni_glove = set(glove_dict.keys())
diff_glove = uni_vali - (uni_vali & uni_glove)
print(f"Difference [Val - (Val & Glove)] unique words: \t{len(diff_glove)}  (val che non sta in glove)")
print(f"Word from Val not seen by Train: {(len(diff_glove) + len(diff))*100/len(uni_vali):.2F}%")
print()

for i,  oov in enumerate(diff_glove):
    if i < 10:
        print(oov)

df2 = df[df['POStagging'].str.contains('wp\$')]
df2[df2['split']=='test']
# Out:
# ['#' '$' "''" ',' '-lrb-' '-rrb-' '.' ':' '``' 'cc' 'cd' 'dt' 'ex' 'fw'
#  'in' 'jj' 'jjr' 'jjs' 'ls' 'md' 'nn' 'nnp' 'nnps' 'nns' 'pdt' 'pos' 'prp'
#  'prp$' 'rb' 'rbr' 'rbs' 'rp' 'sym' 'to' 'uh' 'vb' 'vbd' 'vbg' 'vbn' 'vbp'
#  'vbz' 'wdt' 'wp' 'wp$' 'wrb']
# Unique classes  45
#
# [Training] unique words: 	7355
# [Training & Val] unique words: 	2884
# [Val] unique word: 	5322  (val tolale)
# Difference [Val - (Training & Val)] unique words: 	2438  (val che non sta in train)
# Difference [Val - (Val & Glove)] unique words: 	212  (val che non sta in glove)
# Word from Val not seen by Train: 49.79%
#
# 7\/16
# floating-rate
# 3,040,000
# dydee
# free-enterprise
# potables
# insider-trading
# veraldi
# labor-backed
# mega-stadium
#                                                    text  ... split
# 3518  coleco industries inc. , a once high-flying to...  ...  test
# 3523  but coleco bounced back with the introduction ...  ...  test
# 3742  absorbed in doling out `` feeding frenzy 's ''...  ...  test
# 3874  still , usx fared better than other major stee...  ...  test
#
# [4 rows x 3 columns]

# %%
'''
    check if the tokenizer is working well. 
    The embedding corresponding to the has to be the same if extracted from the 
    glove matrix and from the dictionary created
'''
print(glove_matrix[glove_dict["the"]])
ind = v4_val_to_key["the"]-1
print(v4_matrix[ind])
# Out:
# [-0.038194 -0.24487   0.72812  -0.39961   0.083172  0.043953 -0.39141
#   0.3344   -0.57545   0.087459  0.28787  -0.06731   0.30906  -0.26384
#  -0.13231  -0.20757   0.33395  -0.33848  -0.31743  -0.48336   0.1464
#  -0.37304   0.34577   0.052041  0.44946  -0.46971   0.02628  -0.54155
#  -0.15518  -0.14107  -0.039722  0.28277   0.14393   0.23464  -0.31021
#   0.086173  0.20397   0.52624   0.17164  -0.082378 -0.71787  -0.41531
#   0.20335  -0.12763   0.41367   0.55187   0.57908  -0.33477  -0.36559
#  -0.54857  -0.062892  0.26584   0.30205   0.99775  -0.80481  -3.0243
#   0.01254  -0.36942   2.2167    0.72201  -0.24978   0.92136   0.034514
#   0.46745   1.1079   -0.19358  -0.074575  0.23353  -0.052062 -0.22044
#   0.057162 -0.15806  -0.30798  -0.41625   0.37972   0.15006  -0.53212
#  -0.2055   -1.2526    0.071624  0.70565   0.49744  -0.42063   0.26148
#  -1.538    -0.30223  -0.073438 -0.28312   0.37104  -0.25217   0.016215
#  -0.017099 -0.38984   0.87424  -0.72569  -0.51058  -0.52028  -0.1459
#   0.8278    0.27062 ]
# [-0.038194   -0.24487001  0.72812003 -0.39961001  0.083172    0.043953
#  -0.39140999  0.3344     -0.57545     0.087459    0.28786999 -0.06731
#   0.30906001 -0.26383999 -0.13231    -0.20757     0.33395001 -0.33848
#  -0.31742999 -0.48335999  0.1464     -0.37303999  0.34577     0.052041
#   0.44946    -0.46970999  0.02628    -0.54154998 -0.15518001 -0.14106999
#  -0.039722    0.28277001  0.14393     0.23464    -0.31020999  0.086173
#   0.20397     0.52623999  0.17163999 -0.082378   -0.71787    -0.41531
#   0.20334999 -0.12763     0.41367     0.55186999  0.57907999 -0.33476999
#  -0.36559001 -0.54856998 -0.062892    0.26583999  0.30204999  0.99774998
#  -0.80480999 -3.0243001   0.01254    -0.36941999  2.21670008  0.72201002
#  -0.24978     0.92136002  0.034514    0.46744999  1.10790002 -0.19358
#  -0.074575    0.23353    -0.052062   -0.22044     0.057162   -0.15806
#  -0.30798    -0.41624999  0.37972     0.15006    -0.53211999 -0.20550001
#  -1.25259995  0.071624    0.70564997  0.49744001 -0.42063001  0.26148
#  -1.53799999 -0.30223    -0.073438   -0.28312001  0.37103999 -0.25217
#   0.016215   -0.017099   -0.38984001  0.87423998 -0.72569001 -0.51058
#  -0.52028    -0.1459      0.82779998  0.27061999]

# %% [markdown]
# #TRAIN VARIOUS MODELS

# %%
'''
    train the models.
    variable TRAINING: if True train, if False upload models saved
'''


compile_info = {
    'optimizer': keras.optimizers.Nadam(learning_rate=1e-2),
    'loss': 'categorical_crossentropy',
    'metrics': ['acc']
}

training_info = {
    'verbose': 1,
    'epochs': 10,
    'batch_size': BATCH_SIZE,
    'callbacks': [keras.callbacks.EarlyStopping(monitor='val_acc', 
                                                patience=4,
                                                restore_best_weights=True)]
}

model_params = {
    'compile_info': compile_info,
    'value_to_key': v4_val_to_key,
    'embedding_dim': EMBEDDING_SIZE,
    'max_seq_len': max_seq_len,
    'num_labels': num_classes,
    'embedding_matrix': np.vstack((np.zeros((1, EMBEDDING_SIZE)),
                       v4_matrix)),
    'num_recurrent_units': 32,
    'l2_reg': 1e-4
}

prediction_info = {
    'batch_size': BATCH_SIZE,
    'verbose': 1
}


model_names = ['baseline', 'gru', 'two_lstm', 'two_dense']
if TRAINING:
    models = []
    histories = []
    for m_name in model_names:
        model = Model(m_name, **model_params)
        history = model.train_model(x_train=x_train, y_train=y_train,
                                    x_val=x_val, y_val=y_val, training_info=training_info)
        model.model.save(m_name)
        models.append(model.model)
        histories.append(history)
else:
    models = [keras.models.load_model(m) for m in model_names]
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, None, 64), dtype=tf.float32, name=None), name='bidirectional/concat:0', description="created by layer 'bidirectional'")
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 100)         1083300
#
#  bidirectional (Bidirectiona  (None, None, 64)         34048
#  l)
#
#  time_distributed (TimeDistr  (None, None, 46)         2990
#  ibuted)
#
# =================================================================
# Total params: 1,120,338
# Trainable params: 37,038
# Non-trainable params: 1,083,300
# _________________________________________________________________
# Start training!
# Parameters: {'verbose': 1, 'epochs': 10, 'batch_size': 64, 'callbacks': [<keras.callbacks.EarlyStopping object at 0x7fae87db4310>]}
# Epoch 1/10
# 31/31 [==============================] - 22s 421ms/step - loss: 0.6252 - acc: 0.5078 - val_loss: 0.3384 - val_acc: 0.7563
# Epoch 2/10
# 31/31 [==============================] - 15s 495ms/step - loss: 0.2595 - acc: 0.8117 - val_loss: 0.2130 - val_acc: 0.8438
# Epoch 3/10
# 31/31 [==============================] - 10s 339ms/step - loss: 0.1877 - acc: 0.8613 - val_loss: 0.1782 - val_acc: 0.8668
# Epoch 4/10
# 31/31 [==============================] - 11s 339ms/step - loss: 0.1580 - acc: 0.8821 - val_loss: 0.1544 - val_acc: 0.8854
# Epoch 5/10
# 31/31 [==============================] - 10s 329ms/step - loss: 0.1407 - acc: 0.8942 - val_loss: 0.1539 - val_acc: 0.8733
# Epoch 6/10
# 31/31 [==============================] - 10s 337ms/step - loss: 0.1294 - acc: 0.9022 - val_loss: 0.1394 - val_acc: 0.8910
# Epoch 7/10
# 31/31 [==============================] - 10s 338ms/step - loss: 0.1222 - acc: 0.9080 - val_loss: 0.1283 - val_acc: 0.8984
# Epoch 8/10
# 31/31 [==============================] - 10s 336ms/step - loss: 0.1139 - acc: 0.9154 - val_loss: 0.1352 - val_acc: 0.8864
# Epoch 9/10
# 31/31 [==============================] - 10s 337ms/step - loss: 0.1100 - acc: 0.9174 - val_loss: 0.1227 - val_acc: 0.9006
# Epoch 10/10
# 31/31 [==============================] - 14s 461ms/step - loss: 0.1061 - acc: 0.9214 - val_loss: 0.1172 - val_acc: 0.9068
# Training completed! Showing history...
# Displaying the following history keys:  dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: baseline/assets
# INFO:tensorflow:Assets written to: baseline/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fae87de2910> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fae8758aad0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 79, 100)           1083300
#
#  gru (GRU)                   (None, 79, 32)            12864
#
#  time_distributed_1 (TimeDis  (None, 79, 46)           1518
#  tributed)
#
# =================================================================
# Total params: 1,097,682
# Trainable params: 14,382
# Non-trainable params: 1,083,300
# _________________________________________________________________
# Start training!
# Parameters: {'verbose': 1, 'epochs': 10, 'batch_size': 64, 'callbacks': [<keras.callbacks.EarlyStopping object at 0x7fae87db4310>]}
# Epoch 1/10
# 31/31 [==============================] - 12s 237ms/step - loss: 0.5238 - acc: 0.5674 - val_loss: 0.2751 - val_acc: 0.7819
# Epoch 2/10
# 31/31 [==============================] - 6s 193ms/step - loss: 0.2270 - acc: 0.8210 - val_loss: 0.2005 - val_acc: 0.8347
# Epoch 3/10
# 31/31 [==============================] - 6s 198ms/step - loss: 0.1797 - acc: 0.8557 - val_loss: 0.1733 - val_acc: 0.8572
# Epoch 4/10
# 31/31 [==============================] - 6s 198ms/step - loss: 0.1565 - acc: 0.8757 - val_loss: 0.1577 - val_acc: 0.8688
# Epoch 5/10
# 31/31 [==============================] - 6s 196ms/step - loss: 0.1424 - acc: 0.8882 - val_loss: 0.1533 - val_acc: 0.8720
# Epoch 6/10
# 31/31 [==============================] - 8s 274ms/step - loss: 0.1347 - acc: 0.8938 - val_loss: 0.1469 - val_acc: 0.8799
# Epoch 7/10
# 31/31 [==============================] - 16s 500ms/step - loss: 0.1270 - acc: 0.9007 - val_loss: 0.1447 - val_acc: 0.8796
# Epoch 8/10
# 31/31 [==============================] - 7s 219ms/step - loss: 0.1224 - acc: 0.9037 - val_loss: 0.1394 - val_acc: 0.8827
# Epoch 9/10
# 31/31 [==============================] - 6s 193ms/step - loss: 0.1182 - acc: 0.9069 - val_loss: 0.1371 - val_acc: 0.8886
# Epoch 10/10
# 31/31 [==============================] - 6s 199ms/step - loss: 0.1141 - acc: 0.9112 - val_loss: 0.1333 - val_acc: 0.8907
# Training completed! Showing history...
# Displaying the following history keys:  dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses, gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses, gru_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: gru/assets
# INFO:tensorflow:Assets written to: gru/assets
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x7fae78d3d190> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 79, 100)           1083300
#
#  bidirectional_1 (Bidirectio  (None, 79, 64)           34048
#  nal)
#
#  lstm_2 (LSTM)               (None, 79, 16)            5184
#
#  time_distributed_2 (TimeDis  (None, 79, 46)           782
#  tributed)
#
# =================================================================
# Total params: 1,123,314
# Trainable params: 40,014
# Non-trainable params: 1,083,300
# _________________________________________________________________
# Start training!
# Parameters: {'verbose': 1, 'epochs': 10, 'batch_size': 64, 'callbacks': [<keras.callbacks.EarlyStopping object at 0x7fae87db4310>]}
# Epoch 1/10
# 31/31 [==============================] - 41s 909ms/step - loss: 0.9404 - acc: 0.1278 - val_loss: 0.9546 - val_acc: 0.1349
# Epoch 2/10
# 31/31 [==============================] - 16s 525ms/step - loss: 0.9015 - acc: 0.1658 - val_loss: 0.8072 - val_acc: 0.2376
# Epoch 3/10
# 31/31 [==============================] - 16s 529ms/step - loss: 0.7169 - acc: 0.3018 - val_loss: 0.5994 - val_acc: 0.3916
# Epoch 4/10
# 31/31 [==============================] - 16s 528ms/step - loss: 0.5412 - acc: 0.4762 - val_loss: 0.4705 - val_acc: 0.5609
# Epoch 5/10
# 31/31 [==============================] - 16s 521ms/step - loss: 0.4116 - acc: 0.6387 - val_loss: 0.3627 - val_acc: 0.6864
# Epoch 6/10
# 31/31 [==============================] - 16s 525ms/step - loss: 0.3259 - acc: 0.7353 - val_loss: 0.3225 - val_acc: 0.7377
# Epoch 7/10
# 31/31 [==============================] - 18s 573ms/step - loss: 0.2781 - acc: 0.7878 - val_loss: 0.2606 - val_acc: 0.8071
# Epoch 8/10
# 31/31 [==============================] - 16s 521ms/step - loss: 0.2328 - acc: 0.8290 - val_loss: 0.2251 - val_acc: 0.8318
# Epoch 9/10
# 31/31 [==============================] - 16s 521ms/step - loss: 0.2084 - acc: 0.8454 - val_loss: 0.2101 - val_acc: 0.8386
# Epoch 10/10
# 31/31 [==============================] - 16s 530ms/step - loss: 0.1938 - acc: 0.8555 - val_loss: 0.2017 - val_acc: 0.8432
# Training completed! Showing history...
# Displaying the following history keys:  dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: two_lstm/assets
# INFO:tensorflow:Assets written to: two_lstm/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fadde63d450> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fae7bb5a5d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fadd992f290> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 79, 100)           1083300
#
#  bidirectional_2 (Bidirectio  (None, 79, 64)           34048
#  nal)
#
#  time_distributed_3 (TimeDis  (None, 79, 64)           4160
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 79, 46)           2990
#  tributed)
#
# =================================================================
# Total params: 1,124,498
# Trainable params: 41,198
# Non-trainable params: 1,083,300
# _________________________________________________________________
# Start training!
# Parameters: {'verbose': 1, 'epochs': 10, 'batch_size': 64, 'callbacks': [<keras.callbacks.EarlyStopping object at 0x7fae87db4310>]}
# Epoch 1/10
# 31/31 [==============================] - 24s 422ms/step - loss: 0.8445 - acc: 0.3480 - val_loss: 0.4836 - val_acc: 0.5689
# Epoch 2/10
# 31/31 [==============================] - 11s 349ms/step - loss: 0.3201 - acc: 0.7395 - val_loss: 0.2231 - val_acc: 0.8335
# Epoch 3/10
# 31/31 [==============================] - 11s 346ms/step - loss: 0.2067 - acc: 0.8426 - val_loss: 0.1800 - val_acc: 0.8669
# Epoch 4/10
# 31/31 [==============================] - 11s 346ms/step - loss: 0.1730 - acc: 0.8693 - val_loss: 0.2032 - val_acc: 0.8360
# Epoch 5/10
# 31/31 [==============================] - 11s 348ms/step - loss: 0.1521 - acc: 0.8888 - val_loss: 0.1544 - val_acc: 0.8804
# Epoch 6/10
# 31/31 [==============================] - 11s 344ms/step - loss: 0.1334 - acc: 0.9014 - val_loss: 0.1654 - val_acc: 0.8630
# Epoch 7/10
# 31/31 [==============================] - 11s 342ms/step - loss: 0.1186 - acc: 0.9161 - val_loss: 0.1337 - val_acc: 0.9005
# Epoch 8/10
# 31/31 [==============================] - 11s 346ms/step - loss: 0.1156 - acc: 0.9169 - val_loss: 0.1293 - val_acc: 0.9056
# Epoch 9/10
# 31/31 [==============================] - 17s 572ms/step - loss: 0.1046 - acc: 0.9280 - val_loss: 0.1287 - val_acc: 0.9009
# Epoch 10/10
# 31/31 [==============================] - 14s 438ms/step - loss: 0.3350 - acc: 0.7815 - val_loss: 0.2085 - val_acc: 0.8633
# Training completed! Showing history...
# Displaying the following history keys:  dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])
# WARNING:absl:Found untraced functions such as lstm_cell_8_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: two_dense/assets
# INFO:tensorflow:Assets written to: two_dense/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fadc978c050> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fadd9a28ad0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# #EVALUATION

# %%
def calculate_f1(model, x, y_true):
    '''
        Compute F1 score to evaluate the model. The punctuation is not considered.

        model: model to predict labels
        x: model input
        y_true: correct labels 
    '''
    #start prediction
    print('Predicting on {} samples'.format(x.shape[0]))
    y_pred = model.predict(x, **prediction_info)

    # from one hot to label index
    y_pred_list = []
    y_true_list = []

    punctuation = ['#', '$', "''", ',', '-lrb-', '-rrb-', '.', ':', '``']
    punctuation_toks = [tok[punct] for punct in punctuation]

    for i, sen in enumerate(y_pred):
        for w_pred, w_true in zip(y_pred[i], y_true[i]):
            if np.argmax(w_true) not in punctuation and np.argmax(w_true)!=0:
                y_pred_list.append(np.argmax(w_pred)) 
                y_true_list.append(np.argmax(w_true))

    return sk_metrics.f1_score(y_true_list, y_pred_list, average='macro')
    
#print(calculate_f1(models[0], x_test, y_test))

# %%
'''
    plot f1 scores on the validation set
'''
f1s_val = [round(calculate_f1(m, x_val, y_val), 2) for m in models]
#f1s_test = [round(calculate_f1(m, x_test, y_test), 2) for m in models]
df = pd.DataFrame({'f1_val': f1s_val},index=model_names)
ax = df.plot.bar(rot = 0, figsize=(8, 9), fontsize=16)
ax.legend(loc='upper right', fontsize=12) 
for container in ax.containers:
    ax.bar_label(container, fontsize=12)
# Out:
# Predicting on 1284 samples
# 21/21 [==============================] - 3s 36ms/step
# Predicting on 1284 samples
# 21/21 [==============================] - 1s 16ms/step
# Predicting on 1284 samples
# 21/21 [==============================] - 4s 48ms/step
# Predicting on 1284 samples
# 21/21 [==============================] - 3s 37ms/step

# %%
from keras import regularizers

'''
    Bayesian Optimization hyperparameter tuning for LSTM. 
    Try several combinations of l2 regulatizer and units value. 
'''
def tuner_LSTM(hp) -> keras.Model:
    inputs = keras.layers.Input(shape=(None,))
    x = layers.Embedding(input_dim=len(v4_val_to_key.keys()) + 1,
                                        output_dim=EMBEDDING_SIZE,
                                        mask_zero = True,
                                        input_length=max_seq_len,
                                        weights=[np.vstack((np.zeros((1, EMBEDDING_SIZE)), v4_matrix))],
                                        trainable=False
                                        )(inputs)
    x = layers.Bidirectional(layers.LSTM(hp.Choice('units', [32, 64, 128]), kernel_regularizer = regularizers.l2(hp.Choice("l2", [1e-5, 1e-4, 1e-3])), return_sequences=True))(x)
    outputs = layers.TimeDistributed(layers.Dense(num_classes, activation="softmax"))(x)
    bidirect_model = keras.Model(inputs=inputs, outputs=outputs)
    bidirect_model.compile(optimizer = keras.optimizers.Nadam(learning_rate=1e-2), metrics = ['acc'], loss = 'categorical_crossentropy')
    return bidirect_model


tune_LSTM = kt.BayesianOptimization(
    tuner_LSTM,
    objective='val_acc',
    max_trials = 6)
tune_LSTM.search(x_train, y_train, epochs=5, validation_data=(x_val, y_val))
tune_LSTM.results_summary()
best_model_LSTM = tune_LSTM.get_best_models()[0]
# Out:
# Trial 6 Complete [00h 01m 59s]
# val_acc: 0.923094630241394
#
# Best val_acc So Far: 0.923094630241394
# Total elapsed time: 00h 12m 30s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Results summary
# Results in ./untitled_project
# Showing 10 best trials
# Objective(name='val_acc', direction='max')
# Trial summary
# Hyperparameters:
# units: 128
# l2: 1e-05
# Score: 0.923094630241394
# Trial summary
# Hyperparameters:
# units: 128
# l2: 1e-05
# Score: 0.9221739768981934
# Trial summary
# Hyperparameters:
# units: 128
# l2: 1e-05
# Score: 0.921384871006012
# Trial summary
# Hyperparameters:
# units: 128
# l2: 1e-05
# Score: 0.9180311560630798
# Trial summary
# Hyperparameters:
# units: 32
# l2: 1e-05
# Score: 0.9136252999305725
# Trial summary
# Hyperparameters:
# units: 64
# l2: 0.001
# Score: 0.8793318867683411

# %%
'''
    Bayesian Optimization hyperparameter tuning for GRU. 
    Try several combinations of l2 regulatizer and units value. 
'''

def tuner_GRU(hp) -> keras.Model:
    gru = keras.models.Sequential()
    gru.add(layers.Embedding(input_dim=len(v4_val_to_key.keys()) + 1,
                              output_dim=EMBEDDING_SIZE,
                              input_length=max_seq_len,
                              mask_zero=True,
                              weights=[np.vstack((np.zeros((1, EMBEDDING_SIZE)),v4_matrix))],
                              trainable=False
                              ))
    gru.add(layers.GRU(hp.Choice('units', [32, 64, 128]), return_sequences=True, kernel_regularizer = regularizers.l2(hp.Choice("l2", [1e-5, 1e-4, 1e-3]))))
    gru.add(layers.TimeDistributed(layers.Dense(num_classes, activation="softmax")))
    gru.compile(optimizer = keras.optimizers.Nadam(learning_rate=1e-2), metrics = ['acc'], loss = 'categorical_crossentropy')
    return gru

tune_GRU =kt.BayesianOptimization(
    tuner_GRU,
    objective='val_acc',
    max_trials=6)
tune_GRU.search(x_train, y_train, epochs=5, validation_data=(x_val, y_val))
tune_GRU.results_summary()
best_model_GRU = tune_GRU.get_best_models()[0]
# Out:
# Trial 6 Complete [00h 01m 26s]
# val_acc: 0.9039258360862732
#
# Best val_acc So Far: 0.9073123931884766
# Total elapsed time: 00h 08m 25s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Results summary
# Results in ./untitled_project
# Showing 10 best trials
# Objective(name='val_acc', direction='max')
# Trial summary
# Hyperparameters:
# units: 128
# l2: 1e-05
# Score: 0.9073123931884766
# Trial summary
# Hyperparameters:
# units: 128
# l2: 1e-05
# Score: 0.9046162962913513
# Trial summary
# Hyperparameters:
# units: 128
# l2: 1e-05
# Score: 0.9039258360862732
# Trial summary
# Hyperparameters:
# units: 128
# l2: 1e-05
# Score: 0.9016242623329163
# Trial summary
# Hyperparameters:
# units: 64
# l2: 0.0001
# Score: 0.8913329243659973
# Trial summary
# Hyperparameters:
# units: 32
# l2: 0.0001
# Score: 0.8854475021362305

# %% [markdown]
# #TRAIN AND EVALUATE BEST MODELS

# %%
'''
    train best models for fifty epochs.
    variable TRAINING_BEST: if True train, if False upload models saved
'''

best_model_compile_info = {
    'optimizer': keras.optimizers.Nadam(learning_rate=1e-2),
    'loss': 'categorical_crossentropy',
    'metrics': ['acc']
}

training_info = {
    'verbose': 1,
    'epochs': 50,
    'batch_size': BATCH_SIZE,
    'callbacks': [keras.callbacks.EarlyStopping(monitor='val_acc', 
                                                patience=8,
                                                restore_best_weights=True)]
}

best_model_params = {
    'compile_info': compile_info,
    'value_to_key': v4_val_to_key,
    'embedding_dim': EMBEDDING_SIZE,
    'max_seq_len': max_seq_len,
    'num_labels': num_classes,
    'embedding_matrix': np.vstack((np.zeros((1, EMBEDDING_SIZE)),
                       v4_matrix)),
    'num_recurrent_units': 128,
    'l2_reg': 1e-5
}

best_model_names = ['baseline', 'gru']
if TRAINING_BEST:
    best_models = []
    histories = []
    for m_name in best_model_names:
        model = Model(m_name, **model_params)
        history = model.train_model(x_train=x_train, y_train=y_train,
                                    x_val=x_val, y_val=y_val, training_info=training_info)
        model.model.save("best_"+m_name)
        best_models.append(model.model)
        histories.append(history)
else:
    best_models = [keras.models.load_model("best_"+m) for m in best_model_names]
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, None, 64), dtype=tf.float32, name=None), name='bidirectional/concat:0', description="created by layer 'bidirectional'")
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding_1 (Embedding)     (None, None, 100)         1083300
#
#  bidirectional (Bidirectiona  (None, None, 64)         34048
#  l)
#
#  time_distributed_1 (TimeDis  (None, None, 46)         2990
#  tributed)
#
# =================================================================
# Total params: 1,120,338
# Trainable params: 37,038
# Non-trainable params: 1,083,300
# _________________________________________________________________
# Start training!
# Parameters: {'verbose': 1, 'epochs': 50, 'batch_size': 64, 'callbacks': [<keras.callbacks.EarlyStopping object at 0x7fadc8b41a50>]}
# Epoch 1/50
# 31/31 [==============================] - 21s 426ms/step - loss: 0.5691 - acc: 0.5830 - val_loss: 0.2746 - val_acc: 0.8174
# Epoch 2/50
# 31/31 [==============================] - 11s 342ms/step - loss: 0.2266 - acc: 0.8425 - val_loss: 0.2182 - val_acc: 0.8356
# Epoch 3/50
# 31/31 [==============================] - 11s 346ms/step - loss: 0.1846 - acc: 0.8667 - val_loss: 0.1725 - val_acc: 0.8783
# Epoch 4/50
# 31/31 [==============================] - 11s 342ms/step - loss: 0.1595 - acc: 0.8865 - val_loss: 0.1696 - val_acc: 0.8697
# Epoch 5/50
# 31/31 [==============================] - 11s 347ms/step - loss: 0.1475 - acc: 0.8942 - val_loss: 0.1492 - val_acc: 0.8898
# Epoch 6/50
# 31/31 [==============================] - 11s 346ms/step - loss: 0.1379 - acc: 0.9004 - val_loss: 0.1501 - val_acc: 0.8867
# Epoch 7/50
# 31/31 [==============================] - 11s 343ms/step - loss: 0.1297 - acc: 0.9076 - val_loss: 0.1421 - val_acc: 0.8941
# Epoch 8/50
# 31/31 [==============================] - 11s 346ms/step - loss: 0.1241 - acc: 0.9117 - val_loss: 0.1370 - val_acc: 0.8948
# Epoch 9/50
# 31/31 [==============================] - 11s 345ms/step - loss: 0.1215 - acc: 0.9130 - val_loss: 0.1330 - val_acc: 0.8994
# Epoch 10/50
# 31/31 [==============================] - 11s 341ms/step - loss: 0.1157 - acc: 0.9174 - val_loss: 0.1332 - val_acc: 0.8994
# Epoch 11/50
# 31/31 [==============================] - 11s 343ms/step - loss: 0.1130 - acc: 0.9198 - val_loss: 0.1276 - val_acc: 0.9030
# Epoch 12/50
# 31/31 [==============================] - 11s 345ms/step - loss: 0.1086 - acc: 0.9250 - val_loss: 0.1234 - val_acc: 0.9059
# Epoch 13/50
# 31/31 [==============================] - 11s 348ms/step - loss: 0.1086 - acc: 0.9236 - val_loss: 0.1258 - val_acc: 0.9039
# Epoch 14/50
# 31/31 [==============================] - 11s 343ms/step - loss: 0.1048 - acc: 0.9250 - val_loss: 0.1268 - val_acc: 0.9046
# Epoch 15/50
# 31/31 [==============================] - 11s 344ms/step - loss: 0.1034 - acc: 0.9264 - val_loss: 0.1222 - val_acc: 0.9061
# Epoch 16/50
# 31/31 [==============================] - 11s 346ms/step - loss: 0.0993 - acc: 0.9317 - val_loss: 0.1194 - val_acc: 0.9097
# Epoch 17/50
# 31/31 [==============================] - 11s 347ms/step - loss: 0.0988 - acc: 0.9310 - val_loss: 0.1175 - val_acc: 0.9110
# Epoch 18/50
# 31/31 [==============================] - 11s 342ms/step - loss: 0.0965 - acc: 0.9327 - val_loss: 0.1309 - val_acc: 0.8901
# Epoch 19/50
# 31/31 [==============================] - 11s 348ms/step - loss: 0.0963 - acc: 0.9318 - val_loss: 0.1200 - val_acc: 0.9071
# Epoch 20/50
# 31/31 [==============================] - 10s 339ms/step - loss: 0.0956 - acc: 0.9327 - val_loss: 0.1149 - val_acc: 0.9098
# Epoch 21/50
# 31/31 [==============================] - 11s 343ms/step - loss: 0.0954 - acc: 0.9328 - val_loss: 0.1161 - val_acc: 0.9117
# Epoch 22/50
# 31/31 [==============================] - 11s 347ms/step - loss: 0.0895 - acc: 0.9388 - val_loss: 0.1196 - val_acc: 0.9054
# Epoch 23/50
# 31/31 [==============================] - 11s 344ms/step - loss: 0.0901 - acc: 0.9383 - val_loss: 0.1162 - val_acc: 0.9086
# Epoch 24/50
# 31/31 [==============================] - 11s 342ms/step - loss: 0.0870 - acc: 0.9411 - val_loss: 0.1224 - val_acc: 0.9023
# Epoch 25/50
# 31/31 [==============================] - 11s 344ms/step - loss: 0.0872 - acc: 0.9397 - val_loss: 0.1134 - val_acc: 0.9115
# Epoch 26/50
# 31/31 [==============================] - 10s 336ms/step - loss: 0.0841 - acc: 0.9429 - val_loss: 0.1150 - val_acc: 0.9081
# Epoch 27/50
# 31/31 [==============================] - 10s 333ms/step - loss: 0.0871 - acc: 0.9392 - val_loss: 0.1158 - val_acc: 0.9087
# Epoch 28/50
# 31/31 [==============================] - 10s 335ms/step - loss: 0.0832 - acc: 0.9436 - val_loss: 0.1111 - val_acc: 0.9145
# Epoch 29/50
# 31/31 [==============================] - 10s 335ms/step - loss: 0.0822 - acc: 0.9444 - val_loss: 0.1152 - val_acc: 0.9099
# Epoch 30/50
# 31/31 [==============================] - 10s 337ms/step - loss: 0.0841 - acc: 0.9425 - val_loss: 0.1158 - val_acc: 0.9075
# Epoch 31/50
# 31/31 [==============================] - 10s 336ms/step - loss: 0.0792 - acc: 0.9483 - val_loss: 0.1128 - val_acc: 0.9121
# Epoch 32/50
# 31/31 [==============================] - 10s 331ms/step - loss: 0.0837 - acc: 0.9413 - val_loss: 0.1151 - val_acc: 0.9096
# Epoch 33/50
# 31/31 [==============================] - 10s 331ms/step - loss: 0.0778 - acc: 0.9485 - val_loss: 0.1161 - val_acc: 0.9071
# Epoch 34/50
# 31/31 [==============================] - 10s 335ms/step - loss: 0.0773 - acc: 0.9491 - val_loss: 0.1130 - val_acc: 0.9122
# Epoch 35/50
# 31/31 [==============================] - 10s 334ms/step - loss: 0.0764 - acc: 0.9492 - val_loss: 0.1105 - val_acc: 0.9126
# Epoch 36/50
# 31/31 [==============================] - 10s 334ms/step - loss: 0.0785 - acc: 0.9468 - val_loss: 0.1105 - val_acc: 0.9136
# Training completed! Showing history...
# Displaying the following history keys:  dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: best_baseline/assets
# INFO:tensorflow:Assets written to: best_baseline/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fadccd14e90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fadc51f6c90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 79, 100)           1083300
#
#  gru_1 (GRU)                 (None, 79, 32)            12864
#
#  time_distributed_2 (TimeDis  (None, 79, 46)           1518
#  tributed)
#
# =================================================================
# Total params: 1,097,682
# Trainable params: 14,382
# Non-trainable params: 1,083,300
# _________________________________________________________________
# Start training!
# Parameters: {'verbose': 1, 'epochs': 50, 'batch_size': 64, 'callbacks': [<keras.callbacks.EarlyStopping object at 0x7fadc8b41a50>]}
# Epoch 1/50
# 31/31 [==============================] - 11s 233ms/step - loss: 0.5505 - acc: 0.5383 - val_loss: 0.2866 - val_acc: 0.7669
# Epoch 2/50
# 31/31 [==============================] - 6s 195ms/step - loss: 0.2376 - acc: 0.8120 - val_loss: 0.2165 - val_acc: 0.8181
# Epoch 3/50
# 31/31 [==============================] - 6s 195ms/step - loss: 0.1904 - acc: 0.8476 - val_loss: 0.1822 - val_acc: 0.8495
# Epoch 4/50
# 31/31 [==============================] - 6s 193ms/step - loss: 0.1682 - acc: 0.8651 - val_loss: 0.1700 - val_acc: 0.8531
# Epoch 5/50
# 31/31 [==============================] - 6s 201ms/step - loss: 0.1533 - acc: 0.8755 - val_loss: 0.1603 - val_acc: 0.8637
# Epoch 6/50
# 31/31 [==============================] - 6s 198ms/step - loss: 0.1466 - acc: 0.8806 - val_loss: 0.1577 - val_acc: 0.8659
# Epoch 7/50
# 31/31 [==============================] - 6s 196ms/step - loss: 0.1384 - acc: 0.8880 - val_loss: 0.1555 - val_acc: 0.8650
# Epoch 8/50
# 31/31 [==============================] - 6s 196ms/step - loss: 0.1328 - acc: 0.8928 - val_loss: 0.1550 - val_acc: 0.8691
# Epoch 9/50
# 31/31 [==============================] - 6s 199ms/step - loss: 0.1280 - acc: 0.8963 - val_loss: 0.1477 - val_acc: 0.8755
# Epoch 10/50
# 31/31 [==============================] - 6s 198ms/step - loss: 0.1246 - acc: 0.8991 - val_loss: 0.1415 - val_acc: 0.8781
# Epoch 11/50
# 31/31 [==============================] - 6s 194ms/step - loss: 0.1194 - acc: 0.9035 - val_loss: 0.1382 - val_acc: 0.8838
# Epoch 12/50
# 31/31 [==============================] - 6s 187ms/step - loss: 0.1179 - acc: 0.9051 - val_loss: 0.1368 - val_acc: 0.8830
# Epoch 13/50
# 31/31 [==============================] - 6s 188ms/step - loss: 0.1143 - acc: 0.9080 - val_loss: 0.1359 - val_acc: 0.8837
# Epoch 14/50
# 31/31 [==============================] - 6s 189ms/step - loss: 0.1097 - acc: 0.9127 - val_loss: 0.1348 - val_acc: 0.8847
# Epoch 15/50
# 31/31 [==============================] - 6s 187ms/step - loss: 0.1089 - acc: 0.9126 - val_loss: 0.1346 - val_acc: 0.8837
# Epoch 16/50
# 31/31 [==============================] - 6s 196ms/step - loss: 0.1070 - acc: 0.9148 - val_loss: 0.1344 - val_acc: 0.8874
# Epoch 17/50
# 31/31 [==============================] - 6s 190ms/step - loss: 0.1050 - acc: 0.9159 - val_loss: 0.1338 - val_acc: 0.8896
# Epoch 18/50
# 31/31 [==============================] - 6s 190ms/step - loss: 0.1016 - acc: 0.9213 - val_loss: 0.1324 - val_acc: 0.8870
# Epoch 19/50
# 31/31 [==============================] - 6s 190ms/step - loss: 0.1016 - acc: 0.9193 - val_loss: 0.1343 - val_acc: 0.8853
# Epoch 20/50
# 31/31 [==============================] - 6s 188ms/step - loss: 0.0979 - acc: 0.9239 - val_loss: 0.1335 - val_acc: 0.8878
# Epoch 21/50
# 31/31 [==============================] - 6s 189ms/step - loss: 0.0979 - acc: 0.9224 - val_loss: 0.1329 - val_acc: 0.8877
# Epoch 22/50
# 31/31 [==============================] - 6s 188ms/step - loss: 0.0946 - acc: 0.9274 - val_loss: 0.1331 - val_acc: 0.8882
# Epoch 23/50
# 31/31 [==============================] - 6s 190ms/step - loss: 0.0953 - acc: 0.9258 - val_loss: 0.1309 - val_acc: 0.8903
# Epoch 24/50
# 31/31 [==============================] - 6s 188ms/step - loss: 0.0924 - acc: 0.9285 - val_loss: 0.1327 - val_acc: 0.8897
# Epoch 25/50
# 31/31 [==============================] - 6s 189ms/step - loss: 0.0903 - acc: 0.9303 - val_loss: 0.1371 - val_acc: 0.8840
# Epoch 26/50
# 31/31 [==============================] - 6s 192ms/step - loss: 0.0907 - acc: 0.9300 - val_loss: 0.1315 - val_acc: 0.8896
# Epoch 27/50
# 31/31 [==============================] - 6s 193ms/step - loss: 0.0889 - acc: 0.9321 - val_loss: 0.1343 - val_acc: 0.8888
# Epoch 28/50
# 31/31 [==============================] - 6s 192ms/step - loss: 0.0878 - acc: 0.9331 - val_loss: 0.1335 - val_acc: 0.8862
# Epoch 29/50
# 31/31 [==============================] - 6s 187ms/step - loss: 0.0890 - acc: 0.9318 - val_loss: 0.1355 - val_acc: 0.8887
# Epoch 30/50
# 31/31 [==============================] - 6s 188ms/step - loss: 0.0857 - acc: 0.9351 - val_loss: 0.1326 - val_acc: 0.8911
# Epoch 31/50
# 31/31 [==============================] - 6s 193ms/step - loss: 0.0839 - acc: 0.9374 - val_loss: 0.1351 - val_acc: 0.8878
# Epoch 32/50
# 31/31 [==============================] - 6s 191ms/step - loss: 0.0852 - acc: 0.9351 - val_loss: 0.1394 - val_acc: 0.8816
# Epoch 33/50
# 31/31 [==============================] - 6s 190ms/step - loss: 0.0834 - acc: 0.9377 - val_loss: 0.1339 - val_acc: 0.8895
# Epoch 34/50
# 31/31 [==============================] - 6s 189ms/step - loss: 0.0829 - acc: 0.9381 - val_loss: 0.1350 - val_acc: 0.8908
# Epoch 35/50
# 31/31 [==============================] - 6s 189ms/step - loss: 0.0816 - acc: 0.9387 - val_loss: 0.1343 - val_acc: 0.8900
# Epoch 36/50
# 31/31 [==============================] - 6s 190ms/step - loss: 0.0801 - acc: 0.9403 - val_loss: 0.1344 - val_acc: 0.8918
# Epoch 37/50
# 31/31 [==============================] - 6s 192ms/step - loss: 0.0814 - acc: 0.9398 - val_loss: 0.1346 - val_acc: 0.8882
# Epoch 38/50
# 31/31 [==============================] - 6s 191ms/step - loss: 0.0790 - acc: 0.9417 - val_loss: 0.1345 - val_acc: 0.8890
# Epoch 39/50
# 31/31 [==============================] - 6s 188ms/step - loss: 0.0793 - acc: 0.9410 - val_loss: 0.1342 - val_acc: 0.8906
# Epoch 40/50
# 31/31 [==============================] - 6s 191ms/step - loss: 0.0794 - acc: 0.9408 - val_loss: 0.1400 - val_acc: 0.8851
# Epoch 41/50
# 31/31 [==============================] - 6s 188ms/step - loss: 0.0776 - acc: 0.9438 - val_loss: 0.1367 - val_acc: 0.8903
# Epoch 42/50
# 31/31 [==============================] - 6s 191ms/step - loss: 0.0763 - acc: 0.9448 - val_loss: 0.1350 - val_acc: 0.8911
# Epoch 43/50
# 31/31 [==============================] - 6s 192ms/step - loss: 0.0764 - acc: 0.9436 - val_loss: 0.1380 - val_acc: 0.8858
# Epoch 44/50
# 31/31 [==============================] - 6s 193ms/step - loss: 0.0758 - acc: 0.9458 - val_loss: 0.1404 - val_acc: 0.8885
# Training completed! Showing history...
# Displaying the following history keys:  dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])
# WARNING:absl:Found untraced functions such as gru_cell_1_layer_call_fn, gru_cell_1_layer_call_and_return_conditional_losses, gru_cell_1_layer_call_fn, gru_cell_1_layer_call_and_return_conditional_losses, gru_cell_1_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: best_gru/assets
# INFO:tensorflow:Assets written to: best_gru/assets
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x7fadd78662d0> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
'''
    plot f1 scores on the validation set
'''

f1s_test = [round(calculate_f1(m, x_test, y_test), 2) for m in best_models]
#f1s_test = [round(calculate_f1(m, x_test, y_test), 2) for m in models]
df = pd.DataFrame({'f1_test': f1s_test},index=best_model_names)
ax = df.plot.bar(rot=0, figsize=(6, 9), fontsize=16, color = "#ff7f0e")
ax.legend(loc='upper right', fontsize=12) 
for container in ax.containers:
    ax.bar_label(container, fontsize=12)
# Out:
# Predicting on 644 samples
# 11/11 [==============================] - 0s 35ms/step
# Predicting on 644 samples
# 11/11 [==============================] - 0s 15ms/step

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np


def plot_confusion_matrix(y_true, y_pred, labels,
                          clf_name=None, normalize='true', figsize=(15, 15)):
    """
        This function calculates and plots with matplotlib the confusion matrix
        for some given y_pred, y_true, is slightly different from sklearn's twin
        The function is created with the intent of readability and compactness

    y_true : ground truth (correct) target values.
    y_pred : estimated targets as returned by a classifier.
    labels : dictionary to map numbers to labels
    clf_name : classifier name
    normalize : {'true', 'pred', 'all'}, default=None
        Normalizes confusion matrix over the true (rows), predicted (columns)
        conditions or all the population. If None, confusion matrix will not be
        normalized.
    figsize : tuple, figure size in inches
    """

    assert len(y_true) == len(y_pred), "y_true and y_pred have to have the same length"
    conf_mat = confusion_matrix(y_true, y_pred, normalize=normalize, labels = list(labels.keys()))
    num_classes = len(labels)
    fig, ax = plt.subplots(figsize=figsize)
    fig.patch.set_facecolor("xkcd:white")  # white background for dark themes
    ax.imshow(conf_mat, cmap=plt.get_cmap("RdYlGn"))

    ax.set_xticks(range(num_classes))
    ax.set_yticks(range(num_classes))

    ax.set_xticklabels([labels[i] for i in range(num_classes)])
    ax.set_yticklabels([labels[i] for i in range(num_classes)])

    [ax.text(j, i, f"{conf_mat[i, j]:.2F}", va="center", ha="center", visible = True) #visible False to get heatmap
     for i in range(len(conf_mat)) for j in range(len(conf_mat[0]))]

    plt.title(f"Confusion Matrix {'' if clf_name is None else f'for {clf_name}'}")
    plt.ylabel("True")
    plt.xlabel("Predicted")
    plt.tight_layout()
    plt.show()

# %%
print("Confusion matrices over validation set: ")

def calculate_conf_mat(model, x, y_true, name):
    """
        compute confusion matrix

        model: model to predict labels
        x: model input
        y_true : Ground truth (correct) target values.
        name: model name
    """
    #start prediction
    print('Predicting on {} samples'.format(x.shape[0]))
    y_pred = model.predict(x, **prediction_info)

    # from one hot to label index
    y_pred_list = []
    y_true_list = []

    labels_dict = {np.argmax(val):key for key,val in tok.items()}

    for i, sen in enumerate(y_pred):
        for w_pred, w_true in zip(y_pred[i], y_true[i]):
            if np.argmax(w_true)!=0:
                y_pred_list.append(np.argmax(w_pred)) 
                y_true_list.append(np.argmax(w_true))
    plot_confusion_matrix(y_true_list, y_pred_list, labels=labels_dict, clf_name=name)

for i in range(len(best_models)):
    calculate_conf_mat(best_models[i], x_test, y_test, best_model_names[i])
# Out:
# Confusion matrices over validation set:
# Predicting on 644 samples
# 11/11 [==============================] - 1s 47ms/step
# Predicting on 644 samples
# 11/11 [==============================] - 0s 16ms/step
